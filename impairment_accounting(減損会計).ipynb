# %% [markdown]
# <a href="https://colab.research.google.com/github/marina554/accounting-practice/blob/main/impairment_accounting(%E6%B8%9B%E6%90%8D%E4%BC%9A%E8%A8%88).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Sample data: list of assets
data = {
    'asset_id': ['A001', 'A002', 'A003'],
    'asset_name': ['Machinery', 'Building', 'Trademark'],
    'carrying_amount': [1000000, 5000000, 2000000],  # Carrying amount
    'future_cash_flows': [900000, 4800000, 1500000], # Future cash flows
    'net_selling_price': [850000, 4500000, 1800000]  # Net selling price
}

df = pd.DataFrame(data)

# Calculation of recoverable amount: the higher of value in use and net selling price
df['recoverable_amount'] = df[['future_cash_flows', 'net_selling_price']].max(axis=1)

# Calculation of impairment loss
df['impairment_loss'] = (df['carrying_amount'] - df['recoverable_amount']).clip(lower=0)

# Carrying amount after impairment
df['post_impairment_value'] = df['carrying_amount'] - df['impairment_loss']

# Display results
print(df)
# Out:
#   asset_id asset_name  carrying_amount  future_cash_flows  net_selling_price  \
# 0     A001  Machinery          1000000             900000             850000
# 1     A002   Building          5000000            4800000            4500000
# 2     A003  Trademark          2000000            1500000            1800000
#
#    recoverable_amount  impairment_loss  post_impairment_value
# 0              900000           100000                 900000
# 1             4800000           200000                4800000
# 2             1800000           200000                1800000

# %%
import numpy as np

def present_value(cash_flows, discount_rate):
    """Calculate the present value of future cash flows"""
    return sum(cf / ((1 + discount_rate) ** i) for i, cf in enumerate(cash_flows, start=1))

# Example
cash_flows = [300000, 250000, 200000, 150000]
discount_rate = 0.05
print("Value in use:", round(present_value(cash_flows, discount_rate)))
# Out:
# Value in use: 808645

# %%
import pandas as pd

# サンプルデータ：資産一覧
data = {
    'asset_id': ['A001', 'A002', 'A003'],
    'asset_name': ['機械設備', '建物', '商標権'],
    'carrying_amount': [1000000, 5000000, 2000000],  # 帳簿価額
    'future_cash_flows': [900000, 4800000, 1500000], # 将来キャッシュフロー
    'net_selling_price': [850000, 4500000, 1800000]  # 正味売却価額
}

df = pd.DataFrame(data)

# 回収可能価額の計算：使用価値と正味売却価額のうち大きい方
df['recoverable_amount'] = df[['future_cash_flows', 'net_selling_price']].max(axis=1)

# 減損損失の計算
df['impairment_loss'] = (df['carrying_amount'] - df['recoverable_amount']).clip(lower=0)

# 帳簿価額の減額後残高
df['post_impairment_value'] = df['carrying_amount'] - df['impairment_loss']

# 結果表示
print(df)
# Out:
#   asset_id asset_name  carrying_amount  future_cash_flows  net_selling_price  \
# 0     A001       機械設備          1000000             900000             850000
# 1     A002         建物          5000000            4800000            4500000
# 2     A003        商標権          2000000            1500000            1800000
#
#    recoverable_amount  impairment_loss  post_impairment_value
# 0              900000           100000                 900000
# 1             4800000           200000                4800000
# 2             1800000           200000                1800000

# %%
import numpy as np

def present_value(cash_flows, discount_rate):
    """将来キャッシュフローの現在価値を求める"""
    return sum(cf / ((1 + discount_rate) ** i) for i, cf in enumerate(cash_flows, start=1))

# 例
cash_flows = [300000, 250000, 200000, 150000]
discount_rate = 0.05
print("使用価値:", round(present_value(cash_flows, discount_rate)))
# Out:
# 使用価値: 808645
